# %%
import datetime
import time
from dotenv import load_dotenv
import os
import joblib
import pandas as pd
import opendatasets as od
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# nicolaidegroot
#
# 6900d57ce8d4df31b0a445d890d726bf

# %%
dataset_url = 'https://www.kaggle.com/nelgiriyewithana/apple-quality'
od.download(dataset_url)
download_dir = './apple-quality'
destination_dir = './data'

# Verplaats het CSV-bestand naar de gewenste locatie (2 mappen omhoog)
os.makedirs(destination_dir, exist_ok=True)  # Zorg ervoor dat de bestemmingsmap bestaat
os.rename(os.path.join(download_dir, 'apple_quality.csv'), os.path.join(destination_dir, 'apple_quality.csv'))
os.rmdir(download_dir)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/apple-quality
# ...
# 100%|██████████| 170k/170k [00:00<00:00, 740kB/s]

# %%
df = pd.read_csv(f'../data/apple_quality.csv')

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.isna().sum()
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
df = df[df['Quality'] != 'Created_by_Nidula_Elgiriyewithana']
df = df[df['Acidity'] != 'Created_by_Nidula_Elgiriyewithana']

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# ...

# %%
df=df.drop('A_id',axis=1)
# Remove rows with the string "Created_by_Nidula_Elgiriyewithana"

df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Quality'] = label_encoder.fit_transform(df['Quality'])
print(df)
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity  Quality
# 0     -0.491590483        1
# 1     -0.722809367        1
# 2      2.621636473        0
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
# Define features and target
X = df[['Size','Weight','Sweetness','Crunchiness','Juiciness','Ripeness','Acidity']]
y = df['Quality']

# %%
# Define classifiers
classifiers = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC(),
    'KNN': KNeighborsClassifier()
}

# Define pipeline and perform cross-validation
results = {}
best_score = 0
best_model = None
best_params = None
for clf_name, clf in classifiers.items():
    pipeline = Pipeline([('clf', clf)])
    cv_scores = cross_val_score(pipeline, X, y, cv=5)
    results[clf_name] = cv_scores.mean()
    
    # Check if current classifier outperforms previous best model
    if cv_scores.mean() > best_score:
        best_score = cv_scores.mean()
        best_model = clf_name

# %%
# Display results of cross-validation
print("Results of Cross-Validation:")
for clf_name, score in results.items():
    print(f"{clf_name}: Accuracy - {score:.2f}")

# Optional: You can also select the best performing model

print(f"Best Model: {best_model}")
# Out:
# Results of Cross-Validation:
# Logistic Regression: Accuracy - 0.75
# Decision Tree: Accuracy - 0.81
# Random Forest: Accuracy - 0.88
# SVM: Accuracy - 0.89
# KNN: Accuracy - 0.89
# Best Model: KNeighborsClassifier()

# %% [markdown]
# Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Define the pipeline and parameter grid for GridSearchCV
pipeline = Pipeline([('clf', best_model)])
param_grid = {
    'clf__n_neighbors': [3, 5, 7],
    'clf__weights': ['uniform', 'distance']
} 

# Perform GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X, y)

# Print best parameters and best score
print("\nBest Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'clf__n_neighbors': 7, 'clf__weights': 'distance'}
# Best Accuracy: 0.893

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
print(best_model)
# Out:
# KNeighborsClassifier()

# %%
print(best_model)

def model_zoeker(best_model):
    classifiers = {
        'Logistic Regression': LogisticRegression(),
        'Decision Tree': DecisionTreeClassifier(),
        'Random Forest': RandomForestClassifier(),
        'SVM': SVC(),
        'KNN': KNeighborsClassifier()
    }

    for model_name, model_instance in classifiers.items():
        if isinstance(best_model, type(model_instance)):
            print(model_instance)

# Voorbeeld van hoe je het zou gebruiken:
model_zoeker(best_model)
# Out:
# KNeighborsClassifier()
# KNeighborsClassifier()
